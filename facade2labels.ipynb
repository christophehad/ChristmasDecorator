# %% [markdown]
# This Jupyter notebook was adapted from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2337, done.
# remote: Total 2337 (delta 0), reused 0 (delta 0), pack-reused 2337
# Receiving objects: 100% (2337/2337), 8.09 MiB | 20.26 MiB/s, done.
# Resolving deltas: 100% (1500/1500), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.7.0+cu101)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.8.1+cu101)
# Collecting dominate>=2.4.0
#   Downloading https://files.pythonhosted.org/packages/ef/a8/4354f8122c39e35516a2708746d89db5e339c867abbd8e0179bccee4b7f9/dominate-2.6.0-py2.py3-none-any.whl
# Collecting visdom>=0.1.8.8
#   Downloading https://files.pythonhosted.org/packages/c9/75/e078f5a2e1df7e0d3044749089fc2823e62d029cc027ed8ae5d71fafcbdc/visdom-0.1.8.9.tar.gz (676kB)
#      |████████████████████████████████| 686kB 11.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (20.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.15.0)
# Collecting jsonpatch
#   Downloading https://files.pythonhosted.org/packages/40/d5/6640ac6d1bdd20f44bb6b3c6e6f2f1c525bf0b7595f99c4f38917f995d6b/jsonpatch-1.28-py2.py3-none-any.whl
# Collecting torchfile
#   Downloading https://files.pythonhosted.org/packages/91/af/5b305f86f2d218091af657ddb53f984ecbd9518ca9fe8ef4103a007252c9/torchfile-0.1.0.tar.gz
# Collecting websocket-client
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 44.9MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.10)
# Collecting jsonpointer>=1.9
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Building wheels for collected packages: visdom, torchfile
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655251 sha256=6b63d5f048132eeb0013ad600ef69b070c59fde01f461b88e3a175c3bc703192
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5712 sha256=c4f447fb8132ceaf76f84c10bbbf495d5f9b05fbcd71fc87a8a7d53476f3bd8d
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# Installing collected packages: dominate, jsonpointer, jsonpatch, torchfile, websocket-client, visdom
# Successfully installed dominate-2.6.0 jsonpatch-1.28 jsonpointer-2.0 torchfile-0.1.0 visdom-0.1.8.9 websocket-client-0.57.0

# %% [markdown]
# # Dataset
#
# Download the day2night dataset to test it.

# %%
# !bash ./datasets/download_cyclegan_dataset.sh facades
# Out:
# Specified [facades]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2020-12-15 08:46:48--  https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/facades.zip
# Resolving people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.189.73
# Connecting to people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.189.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35135868 (34M) [application/zip]
# Saving to: ‘./datasets/facades.zip’
#
# ./datasets/facades. 100%[===================>]  33.51M  61.8MB/s    in 0.5s
#
# 2020-12-15 08:46:49 (61.8 MB/s) - ‘./datasets/facades.zip’ saved [35135868/35135868]
#
# Archive:  ./datasets/facades.zip
#    creating: ./datasets/facades/trainA/
#   inflating: ./datasets/facades/trainA/110_A.jpg
#   inflating: ./datasets/facades/trainA/324_A.jpg
#   inflating: ./datasets/facades/trainA/353_A.jpg
#   inflating: ./datasets/facades/trainA/319_A.jpg
#   inflating: ./datasets/facades/trainA/20_A.jpg
#   inflating: ./datasets/facades/trainA/274_A.jpg
#   inflating: ./datasets/facades/trainA/107_A.jpg
#   inflating: ./datasets/facades/trainA/338_A.jpg
#   inflating: ./datasets/facades/trainA/140_A.jpg
#   inflating: ./datasets/facades/trainA/225_A.jpg
#   inflating: ./datasets/facades/trainA/268_A.jpg
#   inflating: ./datasets/facades/trainA/44_A.jpg
#   inflating: ./datasets/facades/trainA/393_A.jpg
#   inflating: ./datasets/facades/trainA/54_A.jpg
#   inflating: ./datasets/facades/trainA/24_A.jpg
#   inflating: ./datasets/facades/trainA/77_A.jpg
#   inflating: ./datasets/facades/trainA/61_A.jpg
#   inflating: ./datasets/facades/trainA/298_A.jpg
#   inflating: ./datasets/facades/trainA/244_A.jpg
#   inflating: ./datasets/facades/trainA/333_A.jpg
#   inflating: ./datasets/facades/trainA/357_A.jpg
#   inflating: ./datasets/facades/trainA/303_A.jpg
#   inflating: ./datasets/facades/trainA/178_A.jpg
#   inflating: ./datasets/facades/trainA/282_A.jpg
#   inflating: ./datasets/facades/trainA/263_A.jpg
#   inflating: ./datasets/facades/trainA/318_A.jpg
#   inflating: ./datasets/facades/trainA/255_A.jpg
#   inflating: ./datasets/facades/trainA/368_A.jpg
#   inflating: ./datasets/facades/trainA/63_A.jpg
#   inflating: ./datasets/facades/trainA/168_A.jpg
#   inflating: ./datasets/facades/trainA/327_A.jpg
#   inflating: ./datasets/facades/trainA/369_A.jpg
#   inflating: ./datasets/facades/trainA/123_A.jpg
#   inflating: ./datasets/facades/trainA/84_A.jpg
#   inflating: ./datasets/facades/trainA/215_A.jpg
#   inflating: ./datasets/facades/trainA/85_A.jpg
#   inflating: ./datasets/facades/trainA/148_A.jpg
#   inflating: ./datasets/facades/trainA/213_A.jpg
#   inflating: ./datasets/facades/trainA/52_A.jpg
#   inflating: ./datasets/facades/trainA/305_A.jpg
#   inflating: ./datasets/facades/trainA/344_A.jpg
#   inflating: ./datasets/facades/trainA/157_A.jpg
#   inflating: ./datasets/facades/trainA/55_A.jpg
#   inflating: ./datasets/facades/trainA/87_A.jpg
#   inflating: ./datasets/facades/trainA/171_A.jpg
#   inflating: ./datasets/facades/trainA/152_A.jpg
#   inflating: ./datasets/facades/trainA/173_A.jpg
#   inflating: ./datasets/facades/trainA/175_A.jpg
#   inflating: ./datasets/facades/trainA/100_A.jpg
#   inflating: ./datasets/facades/trainA/315_A.jpg
#   inflating: ./datasets/facades/trainA/249_A.jpg
#   inflating: ./datasets/facades/trainA/301_A.jpg
#   inflating: ./datasets/facades/trainA/132_A.jpg
#   inflating: ./datasets/facades/trainA/257_A.jpg
#   inflating: ./datasets/facades/trainA/346_A.jpg
#   inflating: ./datasets/facades/trainA/294_A.jpg
#   inflating: ./datasets/facades/trainA/281_A.jpg
#   inflating: ./datasets/facades/trainA/31_A.jpg
#   inflating: ./datasets/facades/trainA/372_A.jpg
#   inflating: ./datasets/facades/trainA/14_A.jpg
#   inflating: ./datasets/facades/trainA/101_A.jpg
#   inflating: ./datasets/facades/trainA/313_A.jpg
#   inflating: ./datasets/facades/trainA/203_A.jpg
#   inflating: ./datasets/facades/trainA/19_A.jpg
#   inflating: ./datasets/facades/trainA/91_A.jpg
#   inflating: ./datasets/facades/trainA/359_A.jpg
#   inflating: ./datasets/facades/trainA/64_A.jpg
#   inflating: ./datasets/facades/trainA/117_A.jpg
#   inflating: ./datasets/facades/trainA/286_A.jpg
#   inflating: ./datasets/facades/trainA/146_A.jpg
#   inflating: ./datasets/facades/trainA/323_A.jpg
#   inflating: ./datasets/facades/trainA/130_A.jpg
#   inflating: ./datasets/facades/trainA/254_A.jpg
#   inflating: ./datasets/facades/trainA/155_A.jpg
#   inflating: ./datasets/facades/trainA/81_A.jpg
#   inflating: ./datasets/facades/trainA/275_A.jpg
#   inflating: ./datasets/facades/trainA/306_A.jpg
#   inflating: ./datasets/facades/trainA/121_A.jpg
#   inflating: ./datasets/facades/trainA/112_A.jpg
#   inflating: ./datasets/facades/trainA/29_A.jpg
#   inflating: ./datasets/facades/trainA/390_A.jpg
#   inflating: ./datasets/facades/trainA/271_A.jpg
#   inflating: ./datasets/facades/trainA/316_A.jpg
#   inflating: ./datasets/facades/trainA/231_A.jpg
#   inflating: ./datasets/facades/trainA/321_A.jpg
#   inflating: ./datasets/facades/trainA/322_A.jpg
#   inflating: ./datasets/facades/trainA/48_A.jpg
#   inflating: ./datasets/facades/trainA/396_A.jpg
#   inflating: ./datasets/facades/trainA/194_A.jpg
#   inflating: ./datasets/facades/trainA/302_A.jpg
#   inflating: ./datasets/facades/trainA/143_A.jpg
#   inflating: ./datasets/facades/trainA/165_A.jpg
#   inflating: ./datasets/facades/trainA/220_A.jpg
#   inflating: ./datasets/facades/trainA/198_A.jpg
#   inflating: ./datasets/facades/trainA/297_A.jpg
#   inflating: ./datasets/facades/trainA/15_A.jpg
#   inflating: ./datasets/facades/trainA/76_A.jpg
#   inflating: ./datasets/facades/trainA/126_A.jpg
#   inflating: ./datasets/facades/trainA/67_A.jpg
#   inflating: ./datasets/facades/trainA/12_A.jpg
#   inflating: ./datasets/facades/trainA/70_A.jpg
#   inflating: ./datasets/facades/trainA/141_A.jpg
#   inflating: ./datasets/facades/trainA/27_A.jpg
#   inflating: ./datasets/facades/trainA/114_A.jpg
#   inflating: ./datasets/facades/trainA/197_A.jpg
#   inflating: ./datasets/facades/trainA/185_A.jpg
#   inflating: ./datasets/facades/trainA/209_A.jpg
#   inflating: ./datasets/facades/trainA/127_A.jpg
#   inflating: ./datasets/facades/trainA/190_A.jpg
#   inflating: ./datasets/facades/trainA/310_A.jpg
#   inflating: ./datasets/facades/trainA/170_A.jpg
#   inflating: ./datasets/facades/trainA/193_A.jpg
#   inflating: ./datasets/facades/trainA/169_A.jpg
#   inflating: ./datasets/facades/trainA/367_A.jpg
#   inflating: ./datasets/facades/trainA/109_A.jpg
#   inflating: ./datasets/facades/trainA/174_A.jpg
#   inflating: ./datasets/facades/trainA/304_A.jpg
#   inflating: ./datasets/facades/trainA/37_A.jpg
#   inflating: ./datasets/facades/trainA/384_A.jpg
#   inflating: ./datasets/facades/trainA/360_A.jpg
#   inflating: ./datasets/facades/trainA/366_A.jpg
#   inflating: ./datasets/facades/trainA/216_A.jpg
#   inflating: ./datasets/facades/trainA/358_A.jpg
#   inflating: ./datasets/facades/trainA/199_A.jpg
#   inflating: ./datasets/facades/trainA/205_A.jpg
#   inflating: ./datasets/facades/trainA/154_A.jpg
#   inflating: ./datasets/facades/trainA/291_A.jpg
#   inflating: ./datasets/facades/trainA/192_A.jpg
#   inflating: ./datasets/facades/trainA/134_A.jpg
#   inflating: ./datasets/facades/trainA/51_A.jpg
#   inflating: ./datasets/facades/trainA/164_A.jpg
#   inflating: ./datasets/facades/trainA/124_A.jpg
#   inflating: ./datasets/facades/trainA/151_A.jpg
#   inflating: ./datasets/facades/trainA/280_A.jpg
#   inflating: ./datasets/facades/trainA/398_A.jpg
#   inflating: ./datasets/facades/trainA/131_A.jpg
#   inflating: ./datasets/facades/trainA/265_A.jpg
#   inflating: ./datasets/facades/trainA/399_A.jpg
#   inflating: ./datasets/facades/trainA/115_A.jpg
#   inflating: ./datasets/facades/trainA/252_A.jpg
#   inflating: ./datasets/facades/trainA/69_A.jpg
#   inflating: ./datasets/facades/trainA/387_A.jpg
#   inflating: ./datasets/facades/trainA/8_A.jpg
#   inflating: ./datasets/facades/trainA/375_A.jpg
#   inflating: ./datasets/facades/trainA/295_A.jpg
#   inflating: ./datasets/facades/trainA/351_A.jpg
#   inflating: ./datasets/facades/trainA/347_A.jpg
#   inflating: ./datasets/facades/trainA/336_A.jpg
#   inflating: ./datasets/facades/trainA/381_A.jpg
#   inflating: ./datasets/facades/trainA/95_A.jpg
#   inflating: ./datasets/facades/trainA/150_A.jpg
#   inflating: ./datasets/facades/trainA/102_A.jpg
#   inflating: ./datasets/facades/trainA/13_A.jpg
#   inflating: ./datasets/facades/trainA/328_A.jpg
#   inflating: ./datasets/facades/trainA/256_A.jpg
#   inflating: ./datasets/facades/trainA/212_A.jpg
#   inflating: ./datasets/facades/trainA/350_A.jpg
#   inflating: ./datasets/facades/trainA/365_A.jpg
#   inflating: ./datasets/facades/trainA/181_A.jpg
#   inflating: ./datasets/facades/trainA/116_A.jpg
#   inflating: ./datasets/facades/trainA/237_A.jpg
#   inflating: ./datasets/facades/trainA/227_A.jpg
#   inflating: ./datasets/facades/trainA/83_A.jpg
#   inflating: ./datasets/facades/trainA/6_A.jpg
#   inflating: ./datasets/facades/trainA/28_A.jpg
#   inflating: ./datasets/facades/trainA/187_A.jpg
#   inflating: ./datasets/facades/trainA/222_A.jpg
#   inflating: ./datasets/facades/trainA/361_A.jpg
#   inflating: ./datasets/facades/trainA/355_A.jpg
#   inflating: ./datasets/facades/trainA/204_A.jpg
#   inflating: ./datasets/facades/trainA/180_A.jpg
#   inflating: ./datasets/facades/trainA/99_A.jpg
#   inflating: ./datasets/facades/trainA/158_A.jpg
#   inflating: ./datasets/facades/trainA/284_A.jpg
#   inflating: ./datasets/facades/trainA/145_A.jpg
#   inflating: ./datasets/facades/trainA/386_A.jpg
#   inflating: ./datasets/facades/trainA/343_A.jpg
#   inflating: ./datasets/facades/trainA/342_A.jpg
#   inflating: ./datasets/facades/trainA/50_A.jpg
#   inflating: ./datasets/facades/trainA/363_A.jpg
#   inflating: ./datasets/facades/trainA/200_A.jpg
#   inflating: ./datasets/facades/trainA/118_A.jpg
#   inflating: ./datasets/facades/trainA/56_A.jpg
#   inflating: ./datasets/facades/trainA/332_A.jpg
#   inflating: ./datasets/facades/trainA/241_A.jpg
#   inflating: ./datasets/facades/trainA/320_A.jpg
#   inflating: ./datasets/facades/trainA/370_A.jpg
#   inflating: ./datasets/facades/trainA/277_A.jpg
#   inflating: ./datasets/facades/trainA/276_A.jpg
#   inflating: ./datasets/facades/trainA/35_A.jpg
#   inflating: ./datasets/facades/trainA/105_A.jpg
#   inflating: ./datasets/facades/trainA/59_A.jpg
#   inflating: ./datasets/facades/trainA/308_A.jpg
#   inflating: ./datasets/facades/trainA/144_A.jpg
#   inflating: ./datasets/facades/trainA/46_A.jpg
#   inflating: ./datasets/facades/trainA/104_A.jpg
#   inflating: ./datasets/facades/trainA/57_A.jpg
#   inflating: ./datasets/facades/trainA/224_A.jpg
#   inflating: ./datasets/facades/trainA/223_A.jpg
#   inflating: ./datasets/facades/trainA/288_A.jpg
#   inflating: ./datasets/facades/trainA/228_A.jpg
#   inflating: ./datasets/facades/trainA/119_A.jpg
#   inflating: ./datasets/facades/trainA/330_A.jpg
#   inflating: ./datasets/facades/trainA/279_A.jpg
#   inflating: ./datasets/facades/trainA/374_A.jpg
#   inflating: ./datasets/facades/trainA/248_A.jpg
#   inflating: ./datasets/facades/trainA/23_A.jpg
#   inflating: ./datasets/facades/trainA/229_A.jpg
#   inflating: ./datasets/facades/trainA/230_A.jpg
#   inflating: ./datasets/facades/trainA/47_A.jpg
#   inflating: ./datasets/facades/trainA/373_A.jpg
#   inflating: ./datasets/facades/trainA/183_A.jpg
#   inflating: ./datasets/facades/trainA/176_A.jpg
#   inflating: ./datasets/facades/trainA/307_A.jpg
#   inflating: ./datasets/facades/trainA/325_A.jpg
#   inflating: ./datasets/facades/trainA/364_A.jpg
#   inflating: ./datasets/facades/trainA/138_A.jpg
#   inflating: ./datasets/facades/trainA/397_A.jpg
#   inflating: ./datasets/facades/trainA/371_A.jpg
#   inflating: ./datasets/facades/trainA/42_A.jpg
#   inflating: ./datasets/facades/trainA/348_A.jpg
#   inflating: ./datasets/facades/trainA/376_A.jpg
#   inflating: ./datasets/facades/trainA/18_A.jpg
#   inflating: ./datasets/facades/trainA/147_A.jpg
#   inflating: ./datasets/facades/trainA/1_A.jpg
#   inflating: ./datasets/facades/trainA/62_A.jpg
#   inflating: ./datasets/facades/trainA/283_A.jpg
#   inflating: ./datasets/facades/trainA/289_A.jpg
#   inflating: ./datasets/facades/trainA/80_A.jpg
#   inflating: ./datasets/facades/trainA/162_A.jpg
#   inflating: ./datasets/facades/trainA/129_A.jpg
#   inflating: ./datasets/facades/trainA/33_A.jpg
#   inflating: ./datasets/facades/trainA/30_A.jpg
#   inflating: ./datasets/facades/trainA/217_A.jpg
#   inflating: ./datasets/facades/trainA/394_A.jpg
#   inflating: ./datasets/facades/trainA/79_A.jpg
#   inflating: ./datasets/facades/trainA/58_A.jpg
#   inflating: ./datasets/facades/trainA/226_A.jpg
#   inflating: ./datasets/facades/trainA/88_A.jpg
#   inflating: ./datasets/facades/trainA/250_A.jpg
#   inflating: ./datasets/facades/trainA/16_A.jpg
#   inflating: ./datasets/facades/trainA/161_A.jpg
#   inflating: ./datasets/facades/trainA/38_A.jpg
#   inflating: ./datasets/facades/trainA/122_A.jpg
#   inflating: ./datasets/facades/trainA/73_A.jpg
#   inflating: ./datasets/facades/trainA/240_A.jpg
#   inflating: ./datasets/facades/trainA/290_A.jpg
#   inflating: ./datasets/facades/trainA/266_A.jpg
#   inflating: ./datasets/facades/trainA/232_A.jpg
#   inflating: ./datasets/facades/trainA/49_A.jpg
#   inflating: ./datasets/facades/trainA/309_A.jpg
#   inflating: ./datasets/facades/trainA/2_A.jpg
#   inflating: ./datasets/facades/trainA/341_A.jpg
#   inflating: ./datasets/facades/trainA/345_A.jpg
#   inflating: ./datasets/facades/trainA/299_A.jpg
#   inflating: ./datasets/facades/trainA/340_A.jpg
#   inflating: ./datasets/facades/trainA/4_A.jpg
#   inflating: ./datasets/facades/trainA/34_A.jpg
#   inflating: ./datasets/facades/trainA/75_A.jpg
#   inflating: ./datasets/facades/trainA/53_A.jpg
#   inflating: ./datasets/facades/trainA/5_A.jpg
#   inflating: ./datasets/facades/trainA/210_A.jpg
#   inflating: ./datasets/facades/trainA/177_A.jpg
#   inflating: ./datasets/facades/trainA/25_A.jpg
#   inflating: ./datasets/facades/trainA/45_A.jpg
#   inflating: ./datasets/facades/trainA/159_A.jpg
#   inflating: ./datasets/facades/trainA/32_A.jpg
#   inflating: ./datasets/facades/trainA/300_A.jpg
#   inflating: ./datasets/facades/trainA/93_A.jpg
#   inflating: ./datasets/facades/trainA/218_A.jpg
#   inflating: ./datasets/facades/trainA/142_A.jpg
#   inflating: ./datasets/facades/trainA/10_A.jpg
#   inflating: ./datasets/facades/trainA/94_A.jpg
#   inflating: ./datasets/facades/trainA/120_A.jpg
#   inflating: ./datasets/facades/trainA/39_A.jpg
#   inflating: ./datasets/facades/trainA/383_A.jpg
#   inflating: ./datasets/facades/trainA/65_A.jpg
#   inflating: ./datasets/facades/trainA/98_A.jpg
#   inflating: ./datasets/facades/trainA/90_A.jpg
#   inflating: ./datasets/facades/trainA/74_A.jpg
#   inflating: ./datasets/facades/trainA/133_A.jpg
#   inflating: ./datasets/facades/trainA/377_A.jpg
#   inflating: ./datasets/facades/trainA/188_A.jpg
#   inflating: ./datasets/facades/trainA/285_A.jpg
#   inflating: ./datasets/facades/trainA/262_A.jpg
#   inflating: ./datasets/facades/trainA/7_A.jpg
#   inflating: ./datasets/facades/trainA/113_A.jpg
#   inflating: ./datasets/facades/trainA/326_A.jpg
#   inflating: ./datasets/facades/trainA/221_A.jpg
#   inflating: ./datasets/facades/trainA/128_A.jpg
#   inflating: ./datasets/facades/trainA/258_A.jpg
#   inflating: ./datasets/facades/trainA/236_A.jpg
#   inflating: ./datasets/facades/trainA/125_A.jpg
#   inflating: ./datasets/facades/trainA/314_A.jpg
#   inflating: ./datasets/facades/trainA/207_A.jpg
#   inflating: ./datasets/facades/trainA/287_A.jpg
#   inflating: ./datasets/facades/trainA/68_A.jpg
#   inflating: ./datasets/facades/trainA/392_A.jpg
#   inflating: ./datasets/facades/trainA/331_A.jpg
#   inflating: ./datasets/facades/trainA/260_A.jpg
#   inflating: ./datasets/facades/trainA/329_A.jpg
#   inflating: ./datasets/facades/trainA/82_A.jpg
#   inflating: ./datasets/facades/trainA/259_A.jpg
#   inflating: ./datasets/facades/trainA/233_A.jpg
#   inflating: ./datasets/facades/trainA/234_A.jpg
#   inflating: ./datasets/facades/trainA/238_A.jpg
#   inflating: ./datasets/facades/trainA/379_A.jpg
#   inflating: ./datasets/facades/trainA/235_A.jpg
#   inflating: ./datasets/facades/trainA/153_A.jpg
#   inflating: ./datasets/facades/trainA/36_A.jpg
#   inflating: ./datasets/facades/trainA/108_A.jpg
#   inflating: ./datasets/facades/trainA/160_A.jpg
#   inflating: ./datasets/facades/trainA/378_A.jpg
#   inflating: ./datasets/facades/trainA/149_A.jpg
#   inflating: ./datasets/facades/trainA/139_A.jpg
#   inflating: ./datasets/facades/trainA/269_A.jpg
#   inflating: ./datasets/facades/trainA/334_A.jpg
#   inflating: ./datasets/facades/trainA/317_A.jpg
#   inflating: ./datasets/facades/trainA/389_A.jpg
#   inflating: ./datasets/facades/trainA/43_A.jpg
#   inflating: ./datasets/facades/trainA/206_A.jpg
#   inflating: ./datasets/facades/trainA/78_A.jpg
#   inflating: ./datasets/facades/trainA/182_A.jpg
#   inflating: ./datasets/facades/trainA/219_A.jpg
#   inflating: ./datasets/facades/trainA/391_A.jpg
#   inflating: ./datasets/facades/trainA/385_A.jpg
#   inflating: ./datasets/facades/trainA/272_A.jpg
#   inflating: ./datasets/facades/trainA/111_A.jpg
#   inflating: ./datasets/facades/trainA/242_A.jpg
#   inflating: ./datasets/facades/trainA/270_A.jpg
#   inflating: ./datasets/facades/trainA/40_A.jpg
#   inflating: ./datasets/facades/trainA/354_A.jpg
#   inflating: ./datasets/facades/trainA/60_A.jpg
#   inflating: ./datasets/facades/trainA/136_A.jpg
#   inflating: ./datasets/facades/trainA/9_A.jpg
#   inflating: ./datasets/facades/trainA/292_A.jpg
#   inflating: ./datasets/facades/trainA/189_A.jpg
#   inflating: ./datasets/facades/trainA/208_A.jpg
#   inflating: ./datasets/facades/trainA/71_A.jpg
#   inflating: ./datasets/facades/trainA/96_A.jpg
#   inflating: ./datasets/facades/trainA/239_A.jpg
#   inflating: ./datasets/facades/trainA/179_A.jpg
#   inflating: ./datasets/facades/trainA/273_A.jpg
#   inflating: ./datasets/facades/trainA/167_A.jpg
#   inflating: ./datasets/facades/trainA/352_A.jpg
#   inflating: ./datasets/facades/trainA/278_A.jpg
#   inflating: ./datasets/facades/trainA/26_A.jpg
#   inflating: ./datasets/facades/trainA/186_A.jpg
#   inflating: ./datasets/facades/trainA/135_A.jpg
#   inflating: ./datasets/facades/trainA/172_A.jpg
#   inflating: ./datasets/facades/trainA/380_A.jpg
#   inflating: ./datasets/facades/trainA/214_A.jpg
#   inflating: ./datasets/facades/trainA/106_A.jpg
#   inflating: ./datasets/facades/trainA/202_A.jpg
#   inflating: ./datasets/facades/trainA/184_A.jpg
#   inflating: ./datasets/facades/trainA/92_A.jpg
#   inflating: ./datasets/facades/trainA/89_A.jpg
#   inflating: ./datasets/facades/trainA/349_A.jpg
#   inflating: ./datasets/facades/trainA/11_A.jpg
#   inflating: ./datasets/facades/trainA/22_A.jpg
#   inflating: ./datasets/facades/trainA/356_A.jpg
#   inflating: ./datasets/facades/trainA/362_A.jpg
#   inflating: ./datasets/facades/trainA/17_A.jpg
#   inflating: ./datasets/facades/trainA/312_A.jpg
#   inflating: ./datasets/facades/trainA/339_A.jpg
#   inflating: ./datasets/facades/trainA/382_A.jpg
#   inflating: ./datasets/facades/trainA/293_A.jpg
#   inflating: ./datasets/facades/trainA/247_A.jpg
#   inflating: ./datasets/facades/trainA/195_A.jpg
#   inflating: ./datasets/facades/trainA/21_A.jpg
#   inflating: ./datasets/facades/trainA/72_A.jpg
#   inflating: ./datasets/facades/trainA/311_A.jpg
#   inflating: ./datasets/facades/trainA/253_A.jpg
#   inflating: ./datasets/facades/trainA/264_A.jpg
#   inflating: ./datasets/facades/trainA/395_A.jpg
#   inflating: ./datasets/facades/trainA/163_A.jpg
#   inflating: ./datasets/facades/trainA/267_A.jpg
#   inflating: ./datasets/facades/trainA/137_A.jpg
#   inflating: ./datasets/facades/trainA/261_A.jpg
#   inflating: ./datasets/facades/trainA/166_A.jpg
#   inflating: ./datasets/facades/trainA/337_A.jpg
#   inflating: ./datasets/facades/trainA/243_A.jpg
#   inflating: ./datasets/facades/trainA/191_A.jpg
#   inflating: ./datasets/facades/trainA/156_A.jpg
#   inflating: ./datasets/facades/trainA/246_A.jpg
#   inflating: ./datasets/facades/trainA/201_A.jpg
#   inflating: ./datasets/facades/trainA/400_A.jpg
#   inflating: ./datasets/facades/trainA/66_A.jpg
#   inflating: ./datasets/facades/trainA/211_A.jpg
#   inflating: ./datasets/facades/trainA/86_A.jpg
#   inflating: ./datasets/facades/trainA/41_A.jpg
#   inflating: ./datasets/facades/trainA/97_A.jpg
#   inflating: ./datasets/facades/trainA/296_A.jpg
#   inflating: ./datasets/facades/trainA/196_A.jpg
#   inflating: ./datasets/facades/trainA/3_A.jpg
#   inflating: ./datasets/facades/trainA/335_A.jpg
#   inflating: ./datasets/facades/trainA/245_A.jpg
#   inflating: ./datasets/facades/trainA/103_A.jpg
#   inflating: ./datasets/facades/trainA/251_A.jpg
#   inflating: ./datasets/facades/trainA/388_A.jpg
#    creating: ./datasets/facades/trainB/
#   inflating: ./datasets/facades/trainB/180_B.jpg
#   inflating: ./datasets/facades/trainB/145_B.jpg
#   inflating: ./datasets/facades/trainB/104_B.jpg
#   inflating: ./datasets/facades/trainB/323_B.jpg
#   inflating: ./datasets/facades/trainB/153_B.jpg
#   inflating: ./datasets/facades/trainB/399_B.jpg
#   inflating: ./datasets/facades/trainB/226_B.jpg
#   inflating: ./datasets/facades/trainB/38_B.jpg
#   inflating: ./datasets/facades/trainB/132_B.jpg
#   inflating: ./datasets/facades/trainB/186_B.jpg
#   inflating: ./datasets/facades/trainB/342_B.jpg
#   inflating: ./datasets/facades/trainB/15_B.jpg
#   inflating: ./datasets/facades/trainB/199_B.jpg
#   inflating: ./datasets/facades/trainB/245_B.jpg
#   inflating: ./datasets/facades/trainB/209_B.jpg
#   inflating: ./datasets/facades/trainB/218_B.jpg
#   inflating: ./datasets/facades/trainB/76_B.jpg
#   inflating: ./datasets/facades/trainB/75_B.jpg
#   inflating: ./datasets/facades/trainB/308_B.jpg
#   inflating: ./datasets/facades/trainB/144_B.jpg
#   inflating: ./datasets/facades/trainB/179_B.jpg
#   inflating: ./datasets/facades/trainB/349_B.jpg
#   inflating: ./datasets/facades/trainB/125_B.jpg
#   inflating: ./datasets/facades/trainB/336_B.jpg
#   inflating: ./datasets/facades/trainB/400_B.jpg
#   inflating: ./datasets/facades/trainB/236_B.jpg
#   inflating: ./datasets/facades/trainB/66_B.jpg
#   inflating: ./datasets/facades/trainB/367_B.jpg
#   inflating: ./datasets/facades/trainB/365_B.jpg
#   inflating: ./datasets/facades/trainB/124_B.jpg
#   inflating: ./datasets/facades/trainB/36_B.jpg
#   inflating: ./datasets/facades/trainB/315_B.jpg
#   inflating: ./datasets/facades/trainB/100_B.jpg
#   inflating: ./datasets/facades/trainB/386_B.jpg
#   inflating: ./datasets/facades/trainB/397_B.jpg
#   inflating: ./datasets/facades/trainB/41_B.jpg
#   inflating: ./datasets/facades/trainB/240_B.jpg
#   inflating: ./datasets/facades/trainB/191_B.jpg
#   inflating: ./datasets/facades/trainB/229_B.jpg
#   inflating: ./datasets/facades/trainB/23_B.jpg
#   inflating: ./datasets/facades/trainB/344_B.jpg
#   inflating: ./datasets/facades/trainB/224_B.jpg
#   inflating: ./datasets/facades/trainB/17_B.jpg
#   inflating: ./datasets/facades/trainB/94_B.jpg
#   inflating: ./datasets/facades/trainB/114_B.jpg
#   inflating: ./datasets/facades/trainB/359_B.jpg
#   inflating: ./datasets/facades/trainB/122_B.jpg
#   inflating: ./datasets/facades/trainB/283_B.jpg
#   inflating: ./datasets/facades/trainB/254_B.jpg
#   inflating: ./datasets/facades/trainB/330_B.jpg
#   inflating: ./datasets/facades/trainB/30_B.jpg
#   inflating: ./datasets/facades/trainB/190_B.jpg
#   inflating: ./datasets/facades/trainB/300_B.jpg
#   inflating: ./datasets/facades/trainB/170_B.jpg
#   inflating: ./datasets/facades/trainB/269_B.jpg
#   inflating: ./datasets/facades/trainB/193_B.jpg
#   inflating: ./datasets/facades/trainB/341_B.jpg
#   inflating: ./datasets/facades/trainB/389_B.jpg
#   inflating: ./datasets/facades/trainB/387_B.jpg
#   inflating: ./datasets/facades/trainB/368_B.jpg
#   inflating: ./datasets/facades/trainB/259_B.jpg
#   inflating: ./datasets/facades/trainB/253_B.jpg
#   inflating: ./datasets/facades/trainB/394_B.jpg
#   inflating: ./datasets/facades/trainB/216_B.jpg
#   inflating: ./datasets/facades/trainB/264_B.jpg
#   inflating: ./datasets/facades/trainB/333_B.jpg
#   inflating: ./datasets/facades/trainB/267_B.jpg
#   inflating: ./datasets/facades/trainB/382_B.jpg
#   inflating: ./datasets/facades/trainB/159_B.jpg
#   inflating: ./datasets/facades/trainB/256_B.jpg
#   inflating: ./datasets/facades/trainB/120_B.jpg
#   inflating: ./datasets/facades/trainB/369_B.jpg
#   inflating: ./datasets/facades/trainB/285_B.jpg
#   inflating: ./datasets/facades/trainB/295_B.jpg
#   inflating: ./datasets/facades/trainB/194_B.jpg
#   inflating: ./datasets/facades/trainB/134_B.jpg
#   inflating: ./datasets/facades/trainB/373_B.jpg
#   inflating: ./datasets/facades/trainB/79_B.jpg
#   inflating: ./datasets/facades/trainB/101_B.jpg
#   inflating: ./datasets/facades/trainB/391_B.jpg
#   inflating: ./datasets/facades/trainB/34_B.jpg
#   inflating: ./datasets/facades/trainB/221_B.jpg
#   inflating: ./datasets/facades/trainB/310_B.jpg
#   inflating: ./datasets/facades/trainB/234_B.jpg
#   inflating: ./datasets/facades/trainB/58_B.jpg
#   inflating: ./datasets/facades/trainB/276_B.jpg
#   inflating: ./datasets/facades/trainB/292_B.jpg
#   inflating: ./datasets/facades/trainB/268_B.jpg
#   inflating: ./datasets/facades/trainB/65_B.jpg
#   inflating: ./datasets/facades/trainB/136_B.jpg
#   inflating: ./datasets/facades/trainB/350_B.jpg
#   inflating: ./datasets/facades/trainB/112_B.jpg
#   inflating: ./datasets/facades/trainB/390_B.jpg
#   inflating: ./datasets/facades/trainB/28_B.jpg
#   inflating: ./datasets/facades/trainB/113_B.jpg
#   inflating: ./datasets/facades/trainB/289_B.jpg
#   inflating: ./datasets/facades/trainB/99_B.jpg
#   inflating: ./datasets/facades/trainB/141_B.jpg
#   inflating: ./datasets/facades/trainB/274_B.jpg
#   inflating: ./datasets/facades/trainB/37_B.jpg
#   inflating: ./datasets/facades/trainB/392_B.jpg
#   inflating: ./datasets/facades/trainB/95_B.jpg
#   inflating: ./datasets/facades/trainB/215_B.jpg
#   inflating: ./datasets/facades/trainB/241_B.jpg
#   inflating: ./datasets/facades/trainB/282_B.jpg
#   inflating: ./datasets/facades/trainB/258_B.jpg
#   inflating: ./datasets/facades/trainB/238_B.jpg
#   inflating: ./datasets/facades/trainB/16_B.jpg
#   inflating: ./datasets/facades/trainB/53_B.jpg
#   inflating: ./datasets/facades/trainB/304_B.jpg
#   inflating: ./datasets/facades/trainB/284_B.jpg
#   inflating: ./datasets/facades/trainB/84_B.jpg
#   inflating: ./datasets/facades/trainB/63_B.jpg
#   inflating: ./datasets/facades/trainB/354_B.jpg
#   inflating: ./datasets/facades/trainB/343_B.jpg
#   inflating: ./datasets/facades/trainB/272_B.jpg
#   inflating: ./datasets/facades/trainB/377_B.jpg
#   inflating: ./datasets/facades/trainB/168_B.jpg
#   inflating: ./datasets/facades/trainB/178_B.jpg
#   inflating: ./datasets/facades/trainB/56_B.jpg
#   inflating: ./datasets/facades/trainB/96_B.jpg
#   inflating: ./datasets/facades/trainB/189_B.jpg
#   inflating: ./datasets/facades/trainB/381_B.jpg
#   inflating: ./datasets/facades/trainB/119_B.jpg
#   inflating: ./datasets/facades/trainB/61_B.jpg
#   inflating: ./datasets/facades/trainB/353_B.jpg
#   inflating: ./datasets/facades/trainB/202_B.jpg
#   inflating: ./datasets/facades/trainB/148_B.jpg
#   inflating: ./datasets/facades/trainB/90_B.jpg
#   inflating: ./datasets/facades/trainB/42_B.jpg
#   inflating: ./datasets/facades/trainB/262_B.jpg
#   inflating: ./datasets/facades/trainB/10_B.jpg
#   inflating: ./datasets/facades/trainB/175_B.jpg
#   inflating: ./datasets/facades/trainB/233_B.jpg
#   inflating: ./datasets/facades/trainB/46_B.jpg
#   inflating: ./datasets/facades/trainB/77_B.jpg
#   inflating: ./datasets/facades/trainB/384_B.jpg
#   inflating: ./datasets/facades/trainB/7_B.jpg
#   inflating: ./datasets/facades/trainB/219_B.jpg
#   inflating: ./datasets/facades/trainB/128_B.jpg
#   inflating: ./datasets/facades/trainB/166_B.jpg
#   inflating: ./datasets/facades/trainB/247_B.jpg
#   inflating: ./datasets/facades/trainB/328_B.jpg
#   inflating: ./datasets/facades/trainB/231_B.jpg
#   inflating: ./datasets/facades/trainB/143_B.jpg
#   inflating: ./datasets/facades/trainB/337_B.jpg
#   inflating: ./datasets/facades/trainB/14_B.jpg
#   inflating: ./datasets/facades/trainB/62_B.jpg
#   inflating: ./datasets/facades/trainB/118_B.jpg
#   inflating: ./datasets/facades/trainB/271_B.jpg
#   inflating: ./datasets/facades/trainB/165_B.jpg
#   inflating: ./datasets/facades/trainB/109_B.jpg
#   inflating: ./datasets/facades/trainB/338_B.jpg
#   inflating: ./datasets/facades/trainB/345_B.jpg
#   inflating: ./datasets/facades/trainB/298_B.jpg
#   inflating: ./datasets/facades/trainB/73_B.jpg
#   inflating: ./datasets/facades/trainB/86_B.jpg
#   inflating: ./datasets/facades/trainB/71_B.jpg
#   inflating: ./datasets/facades/trainB/303_B.jpg
#   inflating: ./datasets/facades/trainB/8_B.jpg
#   inflating: ./datasets/facades/trainB/340_B.jpg
#   inflating: ./datasets/facades/trainB/135_B.jpg
#   inflating: ./datasets/facades/trainB/339_B.jpg
#   inflating: ./datasets/facades/trainB/22_B.jpg
#   inflating: ./datasets/facades/trainB/1_B.jpg
#   inflating: ./datasets/facades/trainB/59_B.jpg
#   inflating: ./datasets/facades/trainB/217_B.jpg
#   inflating: ./datasets/facades/trainB/26_B.jpg
#   inflating: ./datasets/facades/trainB/263_B.jpg
#   inflating: ./datasets/facades/trainB/105_B.jpg
#   inflating: ./datasets/facades/trainB/331_B.jpg
#   inflating: ./datasets/facades/trainB/309_B.jpg
#   inflating: ./datasets/facades/trainB/198_B.jpg
#   inflating: ./datasets/facades/trainB/334_B.jpg
#   inflating: ./datasets/facades/trainB/25_B.jpg
#   inflating: ./datasets/facades/trainB/89_B.jpg
#   inflating: ./datasets/facades/trainB/235_B.jpg
#   inflating: ./datasets/facades/trainB/35_B.jpg
#   inflating: ./datasets/facades/trainB/176_B.jpg
#   inflating: ./datasets/facades/trainB/379_B.jpg
#   inflating: ./datasets/facades/trainB/239_B.jpg
#   inflating: ./datasets/facades/trainB/162_B.jpg
#   inflating: ./datasets/facades/trainB/357_B.jpg
#   inflating: ./datasets/facades/trainB/115_B.jpg
#   inflating: ./datasets/facades/trainB/80_B.jpg
#   inflating: ./datasets/facades/trainB/83_B.jpg
#   inflating: ./datasets/facades/trainB/257_B.jpg
#   inflating: ./datasets/facades/trainB/275_B.jpg
#   inflating: ./datasets/facades/trainB/133_B.jpg
#   inflating: ./datasets/facades/trainB/348_B.jpg
#   inflating: ./datasets/facades/trainB/356_B.jpg
#   inflating: ./datasets/facades/trainB/173_B.jpg
#   inflating: ./datasets/facades/trainB/347_B.jpg
#   inflating: ./datasets/facades/trainB/325_B.jpg
#   inflating: ./datasets/facades/trainB/106_B.jpg
#   inflating: ./datasets/facades/trainB/388_B.jpg
#   inflating: ./datasets/facades/trainB/9_B.jpg
#   inflating: ./datasets/facades/trainB/177_B.jpg
#   inflating: ./datasets/facades/trainB/196_B.jpg
#   inflating: ./datasets/facades/trainB/296_B.jpg
#   inflating: ./datasets/facades/trainB/137_B.jpg
#   inflating: ./datasets/facades/trainB/305_B.jpg
#   inflating: ./datasets/facades/trainB/270_B.jpg
#   inflating: ./datasets/facades/trainB/157_B.jpg
#   inflating: ./datasets/facades/trainB/18_B.jpg
#   inflating: ./datasets/facades/trainB/85_B.jpg
#   inflating: ./datasets/facades/trainB/203_B.jpg
#   inflating: ./datasets/facades/trainB/156_B.jpg
#   inflating: ./datasets/facades/trainB/363_B.jpg
#   inflating: ./datasets/facades/trainB/228_B.jpg
#   inflating: ./datasets/facades/trainB/246_B.jpg
#   inflating: ./datasets/facades/trainB/375_B.jpg
#   inflating: ./datasets/facades/trainB/249_B.jpg
#   inflating: ./datasets/facades/trainB/360_B.jpg
#   inflating: ./datasets/facades/trainB/111_B.jpg
#   inflating: ./datasets/facades/trainB/244_B.jpg
#   inflating: ./datasets/facades/trainB/116_B.jpg
#   inflating: ./datasets/facades/trainB/204_B.jpg
#   inflating: ./datasets/facades/trainB/287_B.jpg
#   inflating: ./datasets/facades/trainB/321_B.jpg
#   inflating: ./datasets/facades/trainB/398_B.jpg
#   inflating: ./datasets/facades/trainB/210_B.jpg
#   inflating: ./datasets/facades/trainB/167_B.jpg
#   inflating: ./datasets/facades/trainB/291_B.jpg
#   inflating: ./datasets/facades/trainB/184_B.jpg
#   inflating: ./datasets/facades/trainB/140_B.jpg
#   inflating: ./datasets/facades/trainB/39_B.jpg
#   inflating: ./datasets/facades/trainB/4_B.jpg
#   inflating: ./datasets/facades/trainB/102_B.jpg
#   inflating: ./datasets/facades/trainB/322_B.jpg
#   inflating: ./datasets/facades/trainB/147_B.jpg
#   inflating: ./datasets/facades/trainB/214_B.jpg
#   inflating: ./datasets/facades/trainB/78_B.jpg
#   inflating: ./datasets/facades/trainB/294_B.jpg
#   inflating: ./datasets/facades/trainB/197_B.jpg
#   inflating: ./datasets/facades/trainB/316_B.jpg
#   inflating: ./datasets/facades/trainB/335_B.jpg
#   inflating: ./datasets/facades/trainB/139_B.jpg
#   inflating: ./datasets/facades/trainB/297_B.jpg
#   inflating: ./datasets/facades/trainB/47_B.jpg
#   inflating: ./datasets/facades/trainB/155_B.jpg
#   inflating: ./datasets/facades/trainB/129_B.jpg
#   inflating: ./datasets/facades/trainB/91_B.jpg
#   inflating: ./datasets/facades/trainB/212_B.jpg
#   inflating: ./datasets/facades/trainB/154_B.jpg
#   inflating: ./datasets/facades/trainB/92_B.jpg
#   inflating: ./datasets/facades/trainB/160_B.jpg
#   inflating: ./datasets/facades/trainB/230_B.jpg
#   inflating: ./datasets/facades/trainB/29_B.jpg
#   inflating: ./datasets/facades/trainB/261_B.jpg
#   inflating: ./datasets/facades/trainB/311_B.jpg
#   inflating: ./datasets/facades/trainB/318_B.jpg
#   inflating: ./datasets/facades/trainB/383_B.jpg
#   inflating: ./datasets/facades/trainB/107_B.jpg
#   inflating: ./datasets/facades/trainB/260_B.jpg
#   inflating: ./datasets/facades/trainB/324_B.jpg
#   inflating: ./datasets/facades/trainB/314_B.jpg
#   inflating: ./datasets/facades/trainB/358_B.jpg
#   inflating: ./datasets/facades/trainB/126_B.jpg
#   inflating: ./datasets/facades/trainB/161_B.jpg
#   inflating: ./datasets/facades/trainB/366_B.jpg
#   inflating: ./datasets/facades/trainB/332_B.jpg
#   inflating: ./datasets/facades/trainB/362_B.jpg
#   inflating: ./datasets/facades/trainB/281_B.jpg
#   inflating: ./datasets/facades/trainB/68_B.jpg
#   inflating: ./datasets/facades/trainB/164_B.jpg
#   inflating: ./datasets/facades/trainB/192_B.jpg
#   inflating: ./datasets/facades/trainB/158_B.jpg
#   inflating: ./datasets/facades/trainB/355_B.jpg
#   inflating: ./datasets/facades/trainB/376_B.jpg
#   inflating: ./datasets/facades/trainB/123_B.jpg
#   inflating: ./datasets/facades/trainB/44_B.jpg
#   inflating: ./datasets/facades/trainB/243_B.jpg
#   inflating: ./datasets/facades/trainB/64_B.jpg
#   inflating: ./datasets/facades/trainB/207_B.jpg
#   inflating: ./datasets/facades/trainB/351_B.jpg
#   inflating: ./datasets/facades/trainB/208_B.jpg
#   inflating: ./datasets/facades/trainB/142_B.jpg
#   inflating: ./datasets/facades/trainB/87_B.jpg
#   inflating: ./datasets/facades/trainB/45_B.jpg
#   inflating: ./datasets/facades/trainB/88_B.jpg
#   inflating: ./datasets/facades/trainB/24_B.jpg
#   inflating: ./datasets/facades/trainB/319_B.jpg
#   inflating: ./datasets/facades/trainB/57_B.jpg
#   inflating: ./datasets/facades/trainB/149_B.jpg
#   inflating: ./datasets/facades/trainB/131_B.jpg
#   inflating: ./datasets/facades/trainB/352_B.jpg
#   inflating: ./datasets/facades/trainB/6_B.jpg
#   inflating: ./datasets/facades/trainB/290_B.jpg
#   inflating: ./datasets/facades/trainB/48_B.jpg
#   inflating: ./datasets/facades/trainB/280_B.jpg
#   inflating: ./datasets/facades/trainB/372_B.jpg
#   inflating: ./datasets/facades/trainB/187_B.jpg
#   inflating: ./datasets/facades/trainB/237_B.jpg
#   inflating: ./datasets/facades/trainB/21_B.jpg
#   inflating: ./datasets/facades/trainB/40_B.jpg
#   inflating: ./datasets/facades/trainB/307_B.jpg
#   inflating: ./datasets/facades/trainB/327_B.jpg
#   inflating: ./datasets/facades/trainB/277_B.jpg
#   inflating: ./datasets/facades/trainB/374_B.jpg
#   inflating: ./datasets/facades/trainB/51_B.jpg
#   inflating: ./datasets/facades/trainB/5_B.jpg
#   inflating: ./datasets/facades/trainB/205_B.jpg
#   inflating: ./datasets/facades/trainB/49_B.jpg
#   inflating: ./datasets/facades/trainB/380_B.jpg
#   inflating: ./datasets/facades/trainB/248_B.jpg
#   inflating: ./datasets/facades/trainB/188_B.jpg
#   inflating: ./datasets/facades/trainB/279_B.jpg
#   inflating: ./datasets/facades/trainB/242_B.jpg
#   inflating: ./datasets/facades/trainB/172_B.jpg
#   inflating: ./datasets/facades/trainB/346_B.jpg
#   inflating: ./datasets/facades/trainB/371_B.jpg
#   inflating: ./datasets/facades/trainB/232_B.jpg
#   inflating: ./datasets/facades/trainB/393_B.jpg
#   inflating: ./datasets/facades/trainB/108_B.jpg
#   inflating: ./datasets/facades/trainB/81_B.jpg
#   inflating: ./datasets/facades/trainB/255_B.jpg
#   inflating: ./datasets/facades/trainB/182_B.jpg
#   inflating: ./datasets/facades/trainB/317_B.jpg
#   inflating: ./datasets/facades/trainB/251_B.jpg
#   inflating: ./datasets/facades/trainB/27_B.jpg
#   inflating: ./datasets/facades/trainB/312_B.jpg
#   inflating: ./datasets/facades/trainB/265_B.jpg
#   inflating: ./datasets/facades/trainB/302_B.jpg
#   inflating: ./datasets/facades/trainB/117_B.jpg
#   inflating: ./datasets/facades/trainB/364_B.jpg
#   inflating: ./datasets/facades/trainB/69_B.jpg
#   inflating: ./datasets/facades/trainB/395_B.jpg
#   inflating: ./datasets/facades/trainB/97_B.jpg
#   inflating: ./datasets/facades/trainB/151_B.jpg
#   inflating: ./datasets/facades/trainB/152_B.jpg
#   inflating: ./datasets/facades/trainB/227_B.jpg
#   inflating: ./datasets/facades/trainB/3_B.jpg
#   inflating: ./datasets/facades/trainB/225_B.jpg
#   inflating: ./datasets/facades/trainB/213_B.jpg
#   inflating: ./datasets/facades/trainB/150_B.jpg
#   inflating: ./datasets/facades/trainB/200_B.jpg
#   inflating: ./datasets/facades/trainB/288_B.jpg
#   inflating: ./datasets/facades/trainB/130_B.jpg
#   inflating: ./datasets/facades/trainB/2_B.jpg
#   inflating: ./datasets/facades/trainB/361_B.jpg
#   inflating: ./datasets/facades/trainB/185_B.jpg
#   inflating: ./datasets/facades/trainB/121_B.jpg
#   inflating: ./datasets/facades/trainB/329_B.jpg
#   inflating: ./datasets/facades/trainB/13_B.jpg
#   inflating: ./datasets/facades/trainB/385_B.jpg
#   inflating: ./datasets/facades/trainB/55_B.jpg
#   inflating: ./datasets/facades/trainB/220_B.jpg
#   inflating: ./datasets/facades/trainB/12_B.jpg
#   inflating: ./datasets/facades/trainB/313_B.jpg
#   inflating: ./datasets/facades/trainB/93_B.jpg
#   inflating: ./datasets/facades/trainB/74_B.jpg
#   inflating: ./datasets/facades/trainB/171_B.jpg
#   inflating: ./datasets/facades/trainB/320_B.jpg
#   inflating: ./datasets/facades/trainB/278_B.jpg
#   inflating: ./datasets/facades/trainB/163_B.jpg
#   inflating: ./datasets/facades/trainB/52_B.jpg
#   inflating: ./datasets/facades/trainB/20_B.jpg
#   inflating: ./datasets/facades/trainB/286_B.jpg
#   inflating: ./datasets/facades/trainB/306_B.jpg
#   inflating: ./datasets/facades/trainB/127_B.jpg
#   inflating: ./datasets/facades/trainB/169_B.jpg
#   inflating: ./datasets/facades/trainB/146_B.jpg
#   inflating: ./datasets/facades/trainB/250_B.jpg
#   inflating: ./datasets/facades/trainB/33_B.jpg
#   inflating: ./datasets/facades/trainB/326_B.jpg
#   inflating: ./datasets/facades/trainB/54_B.jpg
#   inflating: ./datasets/facades/trainB/72_B.jpg
#   inflating: ./datasets/facades/trainB/110_B.jpg
#   inflating: ./datasets/facades/trainB/223_B.jpg
#   inflating: ./datasets/facades/trainB/103_B.jpg
#   inflating: ./datasets/facades/trainB/82_B.jpg
#   inflating: ./datasets/facades/trainB/32_B.jpg
#   inflating: ./datasets/facades/trainB/174_B.jpg
#   inflating: ./datasets/facades/trainB/50_B.jpg
#   inflating: ./datasets/facades/trainB/138_B.jpg
#   inflating: ./datasets/facades/trainB/31_B.jpg
#   inflating: ./datasets/facades/trainB/67_B.jpg
#   inflating: ./datasets/facades/trainB/19_B.jpg
#   inflating: ./datasets/facades/trainB/273_B.jpg
#   inflating: ./datasets/facades/trainB/293_B.jpg
#   inflating: ./datasets/facades/trainB/201_B.jpg
#   inflating: ./datasets/facades/trainB/378_B.jpg
#   inflating: ./datasets/facades/trainB/299_B.jpg
#   inflating: ./datasets/facades/trainB/211_B.jpg
#   inflating: ./datasets/facades/trainB/206_B.jpg
#   inflating: ./datasets/facades/trainB/98_B.jpg
#   inflating: ./datasets/facades/trainB/183_B.jpg
#   inflating: ./datasets/facades/trainB/222_B.jpg
#   inflating: ./datasets/facades/trainB/181_B.jpg
#   inflating: ./datasets/facades/trainB/252_B.jpg
#   inflating: ./datasets/facades/trainB/301_B.jpg
#   inflating: ./datasets/facades/trainB/266_B.jpg
#   inflating: ./datasets/facades/trainB/11_B.jpg
#   inflating: ./datasets/facades/trainB/396_B.jpg
#   inflating: ./datasets/facades/trainB/43_B.jpg
#   inflating: ./datasets/facades/trainB/370_B.jpg
#   inflating: ./datasets/facades/trainB/195_B.jpg
#   inflating: ./datasets/facades/trainB/70_B.jpg
#   inflating: ./datasets/facades/trainB/60_B.jpg
#    creating: ./datasets/facades/testA/
#   inflating: ./datasets/facades/testA/33.jpg
#   inflating: ./datasets/facades/testA/101.jpg
#   inflating: ./datasets/facades/testA/100.jpg
#   inflating: ./datasets/facades/testA/87.jpg
#   inflating: ./datasets/facades/testA/48.jpg
#   inflating: ./datasets/facades/testA/15.jpg
#   inflating: ./datasets/facades/testA/84.jpg
#   inflating: ./datasets/facades/testA/81.jpg
#   inflating: ./datasets/facades/testA/56.jpg
#   inflating: ./datasets/facades/testA/22.jpg
#   inflating: ./datasets/facades/testA/47.jpg
#   inflating: ./datasets/facades/testA/78.jpg
#   inflating: ./datasets/facades/testA/96.jpg
#   inflating: ./datasets/facades/testA/50.jpg
#   inflating: ./datasets/facades/testA/51.jpg
#   inflating: ./datasets/facades/testA/57.jpg
#   inflating: ./datasets/facades/testA/53.jpg
#   inflating: ./datasets/facades/testA/29.jpg
#   inflating: ./datasets/facades/testA/14.jpg
#   inflating: ./datasets/facades/testA/8.jpg
#   inflating: ./datasets/facades/testA/40.jpg
#   inflating: ./datasets/facades/testA/76.jpg
#   inflating: ./datasets/facades/testA/88.jpg
#   inflating: ./datasets/facades/testA/38.jpg
#   inflating: ./datasets/facades/testA/63.jpg
#   inflating: ./datasets/facades/testA/52.jpg
#   inflating: ./datasets/facades/testA/60.jpg
#   inflating: ./datasets/facades/testA/104.jpg
#   inflating: ./datasets/facades/testA/27.jpg
#   inflating: ./datasets/facades/testA/21.jpg
#   inflating: ./datasets/facades/testA/30.jpg
#   inflating: ./datasets/facades/testA/75.jpg
#   inflating: ./datasets/facades/testA/3.jpg
#   inflating: ./datasets/facades/testA/73.jpg
#   inflating: ./datasets/facades/testA/13.jpg
#   inflating: ./datasets/facades/testA/12.jpg
#   inflating: ./datasets/facades/testA/42.jpg
#   inflating: ./datasets/facades/testA/62.jpg
#   inflating: ./datasets/facades/testA/91.jpg
#   inflating: ./datasets/facades/testA/89.jpg
#   inflating: ./datasets/facades/testA/7.jpg
#   inflating: ./datasets/facades/testA/32.jpg
#   inflating: ./datasets/facades/testA/74.jpg
#   inflating: ./datasets/facades/testA/46.jpg
#   inflating: ./datasets/facades/testA/25.jpg
#   inflating: ./datasets/facades/testA/77.jpg
#   inflating: ./datasets/facades/testA/55.jpg
#   inflating: ./datasets/facades/testA/35.jpg
#   inflating: ./datasets/facades/testA/44.jpg
#   inflating: ./datasets/facades/testA/6.jpg
#   inflating: ./datasets/facades/testA/95.jpg
#   inflating: ./datasets/facades/testA/39.jpg
#   inflating: ./datasets/facades/testA/28.jpg
#   inflating: ./datasets/facades/testA/16.jpg
#   inflating: ./datasets/facades/testA/79.jpg
#   inflating: ./datasets/facades/testA/19.jpg
#   inflating: ./datasets/facades/testA/98.jpg
#   inflating: ./datasets/facades/testA/92.jpg
#   inflating: ./datasets/facades/testA/24.jpg
#   inflating: ./datasets/facades/testA/105.jpg
#   inflating: ./datasets/facades/testA/1.jpg
#   inflating: ./datasets/facades/testA/85.jpg
#   inflating: ./datasets/facades/testA/23.jpg
#   inflating: ./datasets/facades/testA/97.jpg
#   inflating: ./datasets/facades/testA/86.jpg
#   inflating: ./datasets/facades/testA/31.jpg
#   inflating: ./datasets/facades/testA/45.jpg
#   inflating: ./datasets/facades/testA/36.jpg
#   inflating: ./datasets/facades/testA/4.jpg
#   inflating: ./datasets/facades/testA/17.jpg
#   inflating: ./datasets/facades/testA/9.jpg
#   inflating: ./datasets/facades/testA/54.jpg
#   inflating: ./datasets/facades/testA/2.jpg
#   inflating: ./datasets/facades/testA/58.jpg
#   inflating: ./datasets/facades/testA/65.jpg
#   inflating: ./datasets/facades/testA/69.jpg
#   inflating: ./datasets/facades/testA/5.jpg
#   inflating: ./datasets/facades/testA/72.jpg
#   inflating: ./datasets/facades/testA/68.jpg
#   inflating: ./datasets/facades/testA/59.jpg
#   inflating: ./datasets/facades/testA/61.jpg
#   inflating: ./datasets/facades/testA/20.jpg
#   inflating: ./datasets/facades/testA/18.jpg
#   inflating: ./datasets/facades/testA/26.jpg
#   inflating: ./datasets/facades/testA/94.jpg
#   inflating: ./datasets/facades/testA/43.jpg
#   inflating: ./datasets/facades/testA/80.jpg
#   inflating: ./datasets/facades/testA/99.jpg
#   inflating: ./datasets/facades/testA/82.jpg
#   inflating: ./datasets/facades/testA/93.jpg
#   inflating: ./datasets/facades/testA/41.jpg
#   inflating: ./datasets/facades/testA/11.jpg
#   inflating: ./datasets/facades/testA/67.jpg
#   inflating: ./datasets/facades/testA/64.jpg
#   inflating: ./datasets/facades/testA/106.jpg
#   inflating: ./datasets/facades/testA/83.jpg
#   inflating: ./datasets/facades/testA/34.jpg
#   inflating: ./datasets/facades/testA/90.jpg
#   inflating: ./datasets/facades/testA/10.jpg
#   inflating: ./datasets/facades/testA/102.jpg
#   inflating: ./datasets/facades/testA/49.jpg
#   inflating: ./datasets/facades/testA/103.jpg
#   inflating: ./datasets/facades/testA/66.jpg
#   inflating: ./datasets/facades/testA/71.jpg
#   inflating: ./datasets/facades/testA/37.jpg
#   inflating: ./datasets/facades/testA/70.jpg
#    creating: ./datasets/facades/testB/
#   inflating: ./datasets/facades/testB/33.jpg
#   inflating: ./datasets/facades/testB/101.jpg
#   inflating: ./datasets/facades/testB/100.jpg
#   inflating: ./datasets/facades/testB/87.jpg
#   inflating: ./datasets/facades/testB/48.jpg
#   inflating: ./datasets/facades/testB/15.jpg
#   inflating: ./datasets/facades/testB/84.jpg
#   inflating: ./datasets/facades/testB/81.jpg
#   inflating: ./datasets/facades/testB/56.jpg
#   inflating: ./datasets/facades/testB/22.jpg
#   inflating: ./datasets/facades/testB/47.jpg
#   inflating: ./datasets/facades/testB/78.jpg
#   inflating: ./datasets/facades/testB/96.jpg
#   inflating: ./datasets/facades/testB/50.jpg
#   inflating: ./datasets/facades/testB/51.jpg
#   inflating: ./datasets/facades/testB/57.jpg
#   inflating: ./datasets/facades/testB/53.jpg
#   inflating: ./datasets/facades/testB/29.jpg
#   inflating: ./datasets/facades/testB/14.jpg
#   inflating: ./datasets/facades/testB/8.jpg
#   inflating: ./datasets/facades/testB/40.jpg
#   inflating: ./datasets/facades/testB/76.jpg
#   inflating: ./datasets/facades/testB/88.jpg
#   inflating: ./datasets/facades/testB/38.jpg
#   inflating: ./datasets/facades/testB/63.jpg
#   inflating: ./datasets/facades/testB/52.jpg
#   inflating: ./datasets/facades/testB/60.jpg
#   inflating: ./datasets/facades/testB/104.jpg
#   inflating: ./datasets/facades/testB/27.jpg
#   inflating: ./datasets/facades/testB/21.jpg
#   inflating: ./datasets/facades/testB/30.jpg
#   inflating: ./datasets/facades/testB/75.jpg
#   inflating: ./datasets/facades/testB/3.jpg
#   inflating: ./datasets/facades/testB/73.jpg
#   inflating: ./datasets/facades/testB/13.jpg
#   inflating: ./datasets/facades/testB/12.jpg
#   inflating: ./datasets/facades/testB/42.jpg
#   inflating: ./datasets/facades/testB/62.jpg
#   inflating: ./datasets/facades/testB/91.jpg
#   inflating: ./datasets/facades/testB/89.jpg
#   inflating: ./datasets/facades/testB/7.jpg
#   inflating: ./datasets/facades/testB/32.jpg
#   inflating: ./datasets/facades/testB/74.jpg
#   inflating: ./datasets/facades/testB/46.jpg
#   inflating: ./datasets/facades/testB/25.jpg
#   inflating: ./datasets/facades/testB/77.jpg
#   inflating: ./datasets/facades/testB/55.jpg
#   inflating: ./datasets/facades/testB/35.jpg
#   inflating: ./datasets/facades/testB/44.jpg
#   inflating: ./datasets/facades/testB/6.jpg
#   inflating: ./datasets/facades/testB/95.jpg
#   inflating: ./datasets/facades/testB/39.jpg
#   inflating: ./datasets/facades/testB/28.jpg
#   inflating: ./datasets/facades/testB/16.jpg
#   inflating: ./datasets/facades/testB/79.jpg
#   inflating: ./datasets/facades/testB/19.jpg
#   inflating: ./datasets/facades/testB/98.jpg
#   inflating: ./datasets/facades/testB/92.jpg
#   inflating: ./datasets/facades/testB/24.jpg
#   inflating: ./datasets/facades/testB/105.jpg
#   inflating: ./datasets/facades/testB/1.jpg
#   inflating: ./datasets/facades/testB/85.jpg
#   inflating: ./datasets/facades/testB/23.jpg
#   inflating: ./datasets/facades/testB/97.jpg
#   inflating: ./datasets/facades/testB/86.jpg
#   inflating: ./datasets/facades/testB/31.jpg
#   inflating: ./datasets/facades/testB/45.jpg
#   inflating: ./datasets/facades/testB/36.jpg
#   inflating: ./datasets/facades/testB/4.jpg
#   inflating: ./datasets/facades/testB/17.jpg
#   inflating: ./datasets/facades/testB/9.jpg
#   inflating: ./datasets/facades/testB/54.jpg
#   inflating: ./datasets/facades/testB/2.jpg
#   inflating: ./datasets/facades/testB/58.jpg
#   inflating: ./datasets/facades/testB/65.jpg
#   inflating: ./datasets/facades/testB/69.jpg
#   inflating: ./datasets/facades/testB/5.jpg
#   inflating: ./datasets/facades/testB/72.jpg
#   inflating: ./datasets/facades/testB/68.jpg
#   inflating: ./datasets/facades/testB/59.jpg
#   inflating: ./datasets/facades/testB/61.jpg
#   inflating: ./datasets/facades/testB/20.jpg
#   inflating: ./datasets/facades/testB/18.jpg
#   inflating: ./datasets/facades/testB/26.jpg
#   inflating: ./datasets/facades/testB/94.jpg
#   inflating: ./datasets/facades/testB/43.jpg
#   inflating: ./datasets/facades/testB/80.jpg
#   inflating: ./datasets/facades/testB/99.jpg
#   inflating: ./datasets/facades/testB/82.jpg
#   inflating: ./datasets/facades/testB/93.jpg
#   inflating: ./datasets/facades/testB/41.jpg
#   inflating: ./datasets/facades/testB/11.jpg
#   inflating: ./datasets/facades/testB/67.jpg
#   inflating: ./datasets/facades/testB/64.jpg
#   inflating: ./datasets/facades/testB/106.jpg
#   inflating: ./datasets/facades/testB/83.jpg
#   inflating: ./datasets/facades/testB/34.jpg
#   inflating: ./datasets/facades/testB/90.jpg
#   inflating: ./datasets/facades/testB/10.jpg
#   inflating: ./datasets/facades/testB/102.jpg
#   inflating: ./datasets/facades/testB/49.jpg
#   inflating: ./datasets/facades/testB/103.jpg
#   inflating: ./datasets/facades/testB/66.jpg
#   inflating: ./datasets/facades/testB/71.jpg
#   inflating: ./datasets/facades/testB/37.jpg
#   inflating: ./datasets/facades/testB/70.jpg

# %% [markdown]
# # Pretrained Model
# Download the official pretrained model for photo2label:

# %%
# !bash ./scripts/download_cyclegan_model.sh facades_photo2label
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [facades_photo2label]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2020-12-15 08:43:28--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/facades_photo2label.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.189.73
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.189.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/facades_photo2label_pretrained/latest_net_G.pth’
#
# ./checkpoints/facad 100%[===================>]  43.46M  68.5MB/s    in 0.6s
#
# 2020-12-15 08:43:29 (68.5 MB/s) - ‘./checkpoints/facades_photo2label_pretrained/latest_net_G.pth’ saved [45575747/45575747]

# %% [markdown]
# # Testing
#
# On test dataset:

# %%
# !python test.py --dataroot datasets/facades/trainC --name facades_photo2label_pretrained --crop_size 256 --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/facades/trainC       	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: facades_photo2label_pretrained	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: instance
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints/facades_photo2label_pretrained/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 11.378 M
# -----------------------------------------------
# creating web directory ./results/facades_photo2label_pretrained/test_latest
# processing (0000)-th image... ['datasets/facades/trainC/facade_aligned_C.jpg']

# %% [markdown]
# # Visualize
#
# Plot results

# %%
ls ./results/facades_photo2label_pretrained/test_latest/images
# Out:
# facade_aligned_C_fake.png  facade_aligned_uncropped_fake.png
# facade_aligned_C_real.png  facade_aligned_uncropped_real.png

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mkdir ./datasets/facades/trainC

# %%
cp /content/drive/MyDrive/Colab\ Notebooks/facade_to_align_aligned_uncropped.jpg ./datasets/facades/trainC/facade_aligned_uncropped.jpg

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/facades_photo2label_pretrained/test_latest/images/103_fake.png')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-80a2f05e7d3e> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 img = plt.imread('./results/facades_photo2label_pretrained/test_latest/images/103_fake.png')
#       4 plt.imshow(img)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2059 @docstring.copy(matplotlib.image.imread)
#    2060 def imread(fname, format=None):
# -> 2061     return matplotlib.image.imread(fname, format)
#    2062
#    2063
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1472             fd = BytesIO(request.urlopen(fname).read())
#    1473             return _png.read_png(fd)
# -> 1474     with cbook.open_file_cm(fname, "rb") as file:
#    1475         return _png.read_png(file)
#    1476
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/facades_photo2label_pretrained/test_latest/images/103_fake.png'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-c9b66d186949> in <module>()
# ----> 1 img = plt.imread('./datasets/facades/trainB/377_B.png')
#       2 plt.imshow(img)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2059 @docstring.copy(matplotlib.image.imread)
#    2060 def imread(fname, format=None):
# -> 2061     return matplotlib.image.imread(fname, format)
#    2062
#    2063
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1472             fd = BytesIO(request.urlopen(fname).read())
#    1473             return _png.read_png(fd)
# -> 1474     with cbook.open_file_cm(fname, "rb") as file:
#    1475         return _png.read_png(file)
#    1476
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/facades/trainB/377_B.png'

# %%
from google.colab import files
# !zip -r ./results/facades_photo2label_pretrained/test_latest/images/test.zip ./results/facades_photo2label_pretrained/test_latest/images
files.download('./results/facades_photo2label_pretrained/test_latest/images/test.zip')
# Out:
#   adding: results/facades_photo2label_pretrained/test_latest/images/ (stored 0%)
#   adding: results/facades_photo2label_pretrained/test_latest/images/facade_aligned_C_real.png (deflated 0%)
#   adding: results/facades_photo2label_pretrained/test_latest/images/facade_aligned_uncropped_real.png (deflated 0%)
#   adding: results/facades_photo2label_pretrained/test_latest/images/facade_aligned_uncropped_fake.png (deflated 0%)
#   adding: results/facades_photo2label_pretrained/test_latest/images/facade_aligned_C_fake.png (deflated 0%)
